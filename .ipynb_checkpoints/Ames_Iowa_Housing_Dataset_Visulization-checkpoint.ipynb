# %% [markdown]
# ## Ames Iowa Hosing Dataset Data Visulization
# ### Author: Yin Deascentis
# Use data visulization to explore the dataset and see the pattern of data and each features.

# %% [markdown]
# ### Load Data

# %%
# Import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import scipy.stats as st
# %pylab inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Check to see if the file path contain the dataset.
from subprocess import check_output
print(check_output(["ls", "./House Prices Dataset"]).decode("utf8"))
# Out:
# test.csv
# train.csv

# %%
# Load the datasets(train and test)
# use pandas to read the file name as string
df_train = pd.read_csv('./House Prices Dataset/train.csv') 
df_test = pd.read_csv('./House Prices Dataset/test.csv')

# %%
#see what we have in the training dataset
print("df_train contain: \n")
df_train.head(5)
# Out:
# df_train contain:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#see what we have in the test dataset
print("df_test contain: \n")
df_test.head(5)
# Out:
# df_test contain:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# as we can tell from training and test data set that the test dataset does not have the SalePrice data

# %%
# identify the target variable of the training dataset -- SalePrice
salePrice = df_train['SalePrice']
# take out the target variable from df_train dataset and rename is as train
train = df_train.drop('SalePrice', 1)

#combined two datasets and named it as data, data without 'SalePrice'
data = pd.concat([train,df_test],ignore_index=True) 

# Drop the "Id" column
ids = df_test["Id"]
data=data.drop("Id", 1)
print ('Ames Iowa housing train dataset has {} data points with {} variables each.'.format(*train.shape))
print ('Ames Iowa housing test dataset has {} data points with {} variables each.'.format(*df_test.shape))
print ('Ames Iowa housing Total dataset has {} data points with {} variables each.'.format(*data.shape))
# Out:
# Ames Iowa housing train dataset has 1460 data points with 80 variables each.
# Ames Iowa housing test dataset has 1459 data points with 80 variables each.
# Ames Iowa housing Total dataset has 2919 data points with 79 variables each.

# %% [markdown]
# ### Data Exploration through visualization

# %%
data.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  2919.000000  2433.000000    2919.000000  2919.000000  2919.000000
# mean     57.137718    69.305795   10168.114080     6.089072     5.564577
# std      42.517628    23.344905    7886.996359     1.409947     1.113131
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7478.000000     5.000000     5.000000
# 50%      50.000000    68.000000    9453.000000     6.000000     5.000000
# 75%      70.000000    80.000000   11570.000000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  2919.000000   2919.000000  2896.000000  2918.000000  2918.000000
# mean   1971.312778   1984.264474   102.201312   441.423235    49.582248
# std      30.291442     20.894344   179.334253   455.610826   169.205611
# ...

# %%
data.hist(figsize=(16,20), bins=50, xlabelsize=6, ylabelsize=6);

# %%
#heatmap to explaint the correlation coefficient
corr = data.select_dtypes(include = ['float64', 'int64']).iloc[:, 1:].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(corr, vmax=1, square=True);

# %% [markdown]
# ### Data Checking and Cleaning
# First look at the missing data

# %%
# See where are the NaN's
def missing_data():
    return data.columns[data.isnull().any()].tolist()

column_missing_data = data[missing_data()].isnull().sum()
column_missing_data.sort(axis=0, ascending=False, kind='quicksort', na_position='last', inplace= True)
print(column_missing_data)
print('Total of missing data: ', data.isnull().values.sum())
# Out:
# PoolQC          2909
# MiscFeature     2814
# Alley           2721
# Fence           2348
# FireplaceQu     1420
# LotFrontage      486
# GarageFinish     159
# GarageYrBlt      159
# GarageQual       159
# GarageCond       159
# GarageType       157
# BsmtExposure      82
# BsmtCond          82
# BsmtQual          81
# BsmtFinType2      80
# BsmtFinType1      79
# MasVnrType        24
# MasVnrArea        23
# MSZoning           4
# BsmtFullBath       2
# BsmtHalfBath       2
# Utilities          2
# Functional         2
# Exterior2nd        1
# Exterior1st        1
# SaleType           1
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtUnfSF          1
# Electrical         1
# KitchenQual        1
# GarageCars         1
# GarageArea         1
# TotalBsmtSF        1
# dtype: int64
# Total of missing data:  13965

# %%
plt.figure(figsize=(16,20))
column_missing_data.plot.bar();

# %%
#relationship between Pool Area and the SalePrice
pool_sale_data = pd.concat([data['PoolArea'],salePrice], axis=1)
pool_sale_data.plot.scatter(x='PoolArea', y='SalePrice');

# %%
# Turn the PoolQC NaN's into 0
data['PoolQC'].fillna(value='None', inplace = True)
pd.crosstab(data.PoolArea, data.PoolQC)
# Out:
# PoolQC    Ex  Fa  Gd  None
# PoolArea
# 0          0   0   0  2906
# 144        1   0   0     0
# 228        1   0   0     0
# 368        0   0   0     1
# 444        0   0   0     1
# 480        0   0   1     0
# 512        1   0   0     0
# 519        0   1   0     0
# 555        1   0   0     0
# 561        0   0   0     1
# 576        0   0   1     0
# 648        0   1   0     0
# 738        0   0   1     0
# 800        0   0   1     0

# %%
#Let's turn MiscFeature into 0
data['MiscFeature'].fillna(value = 'None', inplace=True)

#Let's turn Alley into 0
data['Alley'].fillna(value = 'None', inplace=True)

#Let's turn Fence into 0
data['Fence'].fillna(value = 0, inplace=True)

# %%
#relationship between Fireplaces and the SalePrice
fire_sale_data = pd.concat([data['Fireplaces'],salePrice], axis=1)
fire_sale_data.plot.scatter(x='Fireplaces', y='SalePrice');

# %%
data['FireplaceQu'].fillna(value ='None', inplace=True)
pd.crosstab(data.Fireplaces, data.FireplaceQu)
# Out:
# FireplaceQu  Ex  Fa   Gd  None  Po   TA
# Fireplaces
# 0             0   0    0  1420   0    0
# 1            37  63  627     0  46  495
# 2             5  10  112     0   0   92
# 3             1   1    5     0   0    4
# 4             0   0    0     0   0    1

# %%
#relationship between LotFrontage and the SalePrice
plt.figure(figsize=(16,20))

frontlot_sale_data = pd.concat([data['LotFrontage'],salePrice], axis=1)
frontlot_sale_data.plot.scatter(x='LotFrontage', y='SalePrice');

# %%
data['LotFrontage'].fillna((data['LotFrontage'].mean()), inplace=True)

# %%
# Check out the Garages
garage_cols=['GarageType','GarageQual','GarageCond','GarageYrBlt','GarageFinish','GarageCars','GarageArea']
data[garage_cols][data['GarageType'].isnull()==True].head()
# Out:
#    GarageType GarageQual GarageCond  GarageYrBlt GarageFinish  GarageCars  \
# 39        NaN        NaN        NaN          NaN          NaN         0.0
# 48        NaN        NaN        NaN          NaN          NaN         0.0
# 78        NaN        NaN        NaN          NaN          NaN         0.0
# 88        NaN        NaN        NaN          NaN          NaN         0.0
# 89        NaN        NaN        NaN          NaN          NaN         0.0
#
#     GarageArea
# 39         0.0
# 48         0.0
# 78         0.0
# 88         0.0
# 89         0.0

# %%
# turn NaN into the 0
for cols in garage_cols:
    if data[cols].dtype == np.object:
        data[cols].fillna(value="None", inplace= True)
    else:
        data[cols].fillna(value=0, inplace= True)

# %%
data[garage_cols][data['GarageType'].isnull()==True].head()
# Out:
# Empty DataFrame
# Columns: [GarageType, GarageQual, GarageCond, GarageYrBlt, GarageFinish, GarageCars, GarageArea]
# Index: []

# %%
#relationship between MasVnrArea and the SalePrice
frontlot_sale_data = pd.concat([data['MasVnrArea'],salePrice], axis=1)
frontlot_sale_data.plot.scatter(x='MasVnrArea', y='SalePrice');

# %%
# MasVnrArea NaN ==> 0
data['MasVnrArea'].fillna(value = 0, inplace=True)
#MasVnrType NaN ==> None
data['MasVnrType'].fillna(value = 'None', inplace=True)

# %%
#Only one data missing, so I replace it with the most frequent value
data['Electrical'].fillna(value='SBrkr', inplace=True)

# %% [markdown]
# ### Numerical and Categorical Features

# %%
# Separate the features into two Group Features
categorical_features = data.select_dtypes(include = ["object"]).columns
numerical_features = data.select_dtypes(exclude = ["object"]).columns

# %%
print ('Total Numbers of Numerical features : ' + str(len(numerical_features)))
print ('Numerical features : ', numerical_features.values)
# Out:
# Total Numbers of Numerical features : 36
# Numerical features :  ['MSSubClass' 'LotFrontage' 'LotArea' 'OverallQual' 'OverallCond'
#  'YearBuilt' 'YearRemodAdd' 'MasVnrArea' 'BsmtFinSF1' 'BsmtFinSF2'
#  'BsmtUnfSF' 'TotalBsmtSF' '1stFlrSF' '2ndFlrSF' 'LowQualFinSF' 'GrLivArea'
#  'BsmtFullBath' 'BsmtHalfBath' 'FullBath' 'HalfBath' 'BedroomAbvGr'
#  'KitchenAbvGr' 'TotRmsAbvGrd' 'Fireplaces' 'GarageYrBlt' 'GarageCars'
#  'GarageArea' 'WoodDeckSF' 'OpenPorchSF' 'EnclosedPorch' '3SsnPorch'
#  'ScreenPorch' 'PoolArea' 'MiscVal' 'MoSold' 'YrSold']

# %%
print ('Total Numbers of Categorical features : ' + str(len(categorical_features)))
print('Categorical Features: '+categorical_features.values)
# Out:
# Total Numbers of Categorical features : 43
# ['Categorical Features: MSZoning' 'Categorical Features: Street'
#  'Categorical Features: Alley' 'Categorical Features: LotShape'
#  'Categorical Features: LandContour' 'Categorical Features: Utilities'
#  'Categorical Features: LotConfig' 'Categorical Features: LandSlope'
#  'Categorical Features: Neighborhood' 'Categorical Features: Condition1'
#  'Categorical Features: Condition2' 'Categorical Features: BldgType'
#  'Categorical Features: HouseStyle' 'Categorical Features: RoofStyle'
#  'Categorical Features: RoofMatl' 'Categorical Features: Exterior1st'
#  'Categorical Features: Exterior2nd' 'Categorical Features: MasVnrType'
#  'Categorical Features: ExterQual' 'Categorical Features: ExterCond'
#  'Categorical Features: Foundation' 'Categorical Features: BsmtQual'
#  'Categorical Features: BsmtCond' 'Categorical Features: BsmtExposure'
#  'Categorical Features: BsmtFinType1' 'Categorical Features: BsmtFinType2'
# ...

# %% [markdown]
# ### Numerical features distribution

# %%
num = [n for n in train.columns if train.dtypes[n] != 'object']
num.remove('Id')
f = pd.melt(train, value_vars=num)
g = sns.FacetGrid(f, col="variable",  col_wrap=4, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")

# %% [markdown]
# ### Year Built and Year Remod Add / SalePrice

# %%
price = salePrice.values
fig = plt.figure(2, figsize=(12, 6))
plt.subplot(211)
plt.scatter(df_train.YearBuilt.values, price)
plt.title('YearBuilt')

plt.subplot(212)
plt.scatter(df_train.YearRemodAdd.values, price)
plt.title('YearRemodAdd')

fig.text(-0.01, 0.5, 'Sale Price', va = 'center', rotation = 'vertical', fontsize = 12)

plt.tight_layout()

# %% [markdown]
# ### Kitchen and Bedroom (above grade) / SalePrice

# %%
fig = plt.figure(2, figsize=(12, 6))
plt.subplot(211)
plt.scatter(df_train.KitchenAbvGr.values, price)
plt.title('KitchenAbvGr')

plt.subplot(212)
plt.scatter(df_train.BedroomAbvGr.values, price)
plt.title('BedroomAbvGr')

fig.text(-0.01, 0.5, 'Sale Price', va = 'center', rotation = 'vertical', fontsize = 12)

plt.tight_layout()

# %% [markdown]
# ### Categorical features Boxplot

# %%
# Let's see how many examples we have of SaleCondition
data["SaleCondition"].value_counts()
# Out:
# Normal     2402
# Partial     245
# Abnorml     190
# Family       46
# Alloca       24
# AdjLand      12
# Name: SaleCondition, dtype: int64

# %%
# Show value counts for SaleCondition:
plt.figure(figsize = (12, 6))
ax = sns.countplot(x="SaleCondition", data=data)

# %% [markdown]
# ### Neighborhood
# Physical locations within Ames city limits (map available)

# %%
# Show value counts for Neighborhood:
plt.figure(figsize=(25,10)) 
sns.countplot(x="Neighborhood", data=data)
xt = plt.xticks(rotation=45)

# %%
plt.figure(figsize = (20, 10))
sns.boxplot(x = 'Neighborhood', y = salePrice,  data = data)
xt = plt.xticks(rotation=45)

# %% [markdown]
# ### OverallQual
# ###### Rates the overall material and finish of the house
# *10   Very Excellent
# *9    Excellent
# *8    Very Good
# *7    Good
# *6    Above Average
# *5    Average
# *4    Below Average
# *3    Fair
# *2    Poor
# *1    Very Poor

# %%
# Show value counts for OverallQual:
plt.figure(figsize = (12, 6))
ax = sns.countplot(x="OverallQual", data=data)

# %%
# OverallQual/SalePrice
plt.figure(figsize = (12, 6))
sns.boxplot(x = 'OverallQual', y = salePrice,  data = data)
xt = plt.xticks(rotation=45)

# %%
# KitchenQual/SalePrice
plt.figure(figsize = (12, 6))
sns.boxplot(x = 'KitchenQual', y = salePrice,  data = data)
xt = plt.xticks(rotation=45)
